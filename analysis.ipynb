# %% [markdown]
# # Caricamento dei database

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
comments = pd.read_csv("comments_edited.csv")
courses = pd.read_csv("courses_edited.csv")

#comments

# %%
#courses

# %% [markdown]
# # Esplorazione dei dati

# %% [markdown]
# ## Distribuzione

# %%
comments.hist(bins=20, figsize=(10, 10))
plt.savefig('plot\plot1.png')

plt.show()

courses.hist(bins=20, figsize=(10, 10))
plt.savefig('plot\plot2.png')
plt.show()
